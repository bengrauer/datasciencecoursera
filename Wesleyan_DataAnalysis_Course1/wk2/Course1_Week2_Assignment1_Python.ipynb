# %% [markdown]
# ## BLOG POST - Distribution Counts and Percentages
#
# *Please note I have chosen to use GitHub / Jupyter notebooks in substitute of Tumblr for my blog assignments.*
#
# The variables I have chosen to evaluate are as follows below:
# 1. purpose - This is the purpose of why the loan was requested.  A high level grouping of the loan types.
# 2. int_rate - What interest rate the loan is at
# 3. dti - Debt to income ratio
# 4. revol_util - revolving credit utilization

# %%
# imports
import pandas
import numpy

# %%
# set working directory
directory = '//Project/OneDrive/Coursera/Wesleyan_Course1/wk1_Assignment/'

# %%
# load the data set
pdLoans = pandas.read_csv(directory + 'LoanStats3a.csv', low_memory=False)

# %%
# Convert the data elements - just doing in 
pdLoans["int_rate_d"] = pandas.to_numeric(pdLoans["int_rate"].str.replace('%',''), errors='coerce')
pdLoans["revol_util_d"] = pandas.to_numeric(pdLoans["revol_util"].str.replace('%',''), errors='coerce')

# divide by 100 to get the true percentage
pdLoans["int_rate_d"] = pdLoans["int_rate_d"] / 100.00
pdLoans["revol_util_d"] = pdLoans["revol_util_d"] / 100.00

# %%
# Convert and Bin the data

# %%
# ""purpose" int_rate", "dti", "revol_util" and "recoveries"

# %%
# Examining frequency distributions
print("counts/percentages for purpose of loan")
c1 = pdLoans["purpose"].value_counts(sort=True)
p1 = pdLoans["purpose"].value_counts(sort=True, normalize=True)
print(c1)
print('')
print(p1)
# Out:
# counts/percentages for purpose of loan
# debt_consolidation    19776
# credit_card            5477
# other                  4425
# home_improvement       3199
# major_purchase         2311
# small_business         1992
# car                    1615
# wedding                1004
# medical                 753
# moving                  629
# house                   426
# educational             422
# vacation                400
# renewable_energy        106
# Name: purpose, dtype: int64
#
# debt_consolidation    0.464935
# credit_card           0.128765
# other                 0.104032
# home_improvement      0.075209
# major_purchase        0.054332
# small_business        0.046832
# car                   0.037969
# wedding               0.023604
# medical               0.017703
# moving                0.014788
# house                 0.010015
# educational           0.009921
# vacation              0.009404
# renewable_energy      0.002492
# Name: purpose, dtype: float64

# %%
print("counts/percentages for interest rates")
c1 = pdLoans["int_rate_d"].value_counts(sort=True)
p1 = pdLoans["int_rate_d"].value_counts(sort=True, normalize=True)
print(c1)
print('')
print(p1)
# Out:
# counts/percentages for interest rates
# 0.1099    970
# 0.1149    837
# 0.1349    832
# 0.0751    787
# 0.0788    742
# 0.0749    656
# 0.1171    609
# 0.0999    607
# 0.0790    582
# 0.0542    573
# 0.1199    535
# 0.1269    492
# 0.1037    470
# 0.1299    456
# 0.0603    447
# 0.0849    445
# 0.1242    443
# 0.1065    435
# 0.1186    418
# 0.0579    410
# 0.0890    402
# 0.1059    400
# 0.0729    397
# 0.0662    396
# 0.1427    391
# 0.0963    384
# 0.0991    377
# 0.1253    356
# 0.0599    347
# 0.0714    342
#          ...
# 0.1443      4
# 0.1646      3
# 0.2069      3
# 0.1849      3
# 0.1457      3
# 0.1886      3
# 0.1467      3
# 0.1262      3
# 0.2411      3
# 0.1633      2
# 0.1709      2
# 0.1759      2
# 0.1728      2
# 0.1384      2
# 0.2020      2
# 0.2182      2
# 0.1791      2
# 0.2294      2
# 0.2148      1
# 0.1772      1
# 0.2264      1
# 0.1744      1
# 0.1746      1
# 0.1741      1
# 0.2440      1
# 0.2459      1
# 0.1778      1
# 0.1683      1
# 0.1620      1
# 0.1872      1
# Name: int_rate_d, Length: 394, dtype: int64
#
# 0.1099    0.022805
# 0.1149    0.019678
# 0.1349    0.019560
# 0.0751    0.018502
# 0.0788    0.017444
# 0.0749    0.015423
# 0.1171    0.014318
# 0.0999    0.014271
# 0.0790    0.013683
# 0.0542    0.013471
# 0.1199    0.012578
# 0.1269    0.011567
# 0.1037    0.011050
# 0.1299    0.010721
# 0.0603    0.010509
# 0.0849    0.010462
# 0.1242    0.010415
# 0.1065    0.010227
# 0.1186    0.009827
# 0.0579    0.009639
# 0.0890    0.009451
# 0.1059    0.009404
# 0.0729    0.009333
# 0.0662    0.009310
# 0.1427    0.009192
# 0.0963    0.009028
# 0.0991    0.008863
# 0.1253    0.008370
# 0.0599    0.008158
# 0.0714    0.008040
#             ...
# 0.1443    0.000094
# 0.1646    0.000071
# 0.2069    0.000071
# 0.1849    0.000071
# 0.1457    0.000071
# 0.1886    0.000071
# 0.1467    0.000071
# 0.1262    0.000071
# 0.2411    0.000071
# 0.1633    0.000047
# 0.1709    0.000047
# 0.1759    0.000047
# 0.1728    0.000047
# 0.1384    0.000047
# 0.2020    0.000047
# 0.2182    0.000047
# 0.1791    0.000047
# 0.2294    0.000047
# 0.2148    0.000024
# 0.1772    0.000024
# 0.2264    0.000024
# 0.1744    0.000024
# 0.1746    0.000024
# 0.1741    0.000024
# 0.2440    0.000024
# 0.2459    0.000024
# 0.1778    0.000024
# 0.1683    0.000024
# 0.1620    0.000024
# 0.1872    0.000024
# Name: int_rate_d, Length: 394, dtype: float64

# %%
print("counts/percentages for debt to income ratio")
c1 = pdLoans["dti"].value_counts(sort=True)
p1 = pdLoans["dti"].value_counts(sort=True, normalize=True)
print(c1)
print('')
print(p1)
# Out:
# counts/percentages for debt to income ratio
# 0.00     206
# 12.00     54
# 10.00     46
# 18.00     46
# 19.20     45
# 13.20     43
# 16.80     41
# 13.50     41
# 12.48     40
# 15.00     38
# 14.29     38
# 6.00      37
# 4.80      37
# 20.40     36
# 15.60     35
# 8.40      35
# 21.60     35
# 17.04     35
# 14.44     34
# 12.50     34
# 12.86     34
# 10.80     34
# 9.17      34
# 9.60      34
# 11.50     33
# 17.40     33
# 6.76      33
# 10.64     33
# 13.75     32
# 14.40     32
#         ...
# 29.01      1
# 29.82      1
# 28.16      1
# 27.69      1
# 27.36      1
# 28.43      1
# 28.77      1
# 25.44      1
# 27.23      1
# 29.28      1
# 27.07      1
# 27.10      1
# 26.38      1
# 27.52      1
# 25.58      1
# 25.24      1
# 27.79      1
# 26.74      1
# 25.20      1
# 29.48      1
# 27.03      1
# 28.55      1
# 28.60      1
# 28.64      1
# 27.87      1
# 26.99      1
# 27.81      1
# 27.82      1
# 25.87      1
# 25.37      1
# Name: dti, Length: 2894, dtype: int64
#
# 0.00     0.004843
# 12.00    0.001270
# 10.00    0.001081
# 18.00    0.001081
# 19.20    0.001058
# 13.20    0.001011
# 16.80    0.000964
# 13.50    0.000964
# 12.48    0.000940
# 15.00    0.000893
# 14.29    0.000893
# 6.00     0.000870
# 4.80     0.000870
# 20.40    0.000846
# 15.60    0.000823
# 8.40     0.000823
# 21.60    0.000823
# 17.04    0.000823
# 14.44    0.000799
# 12.50    0.000799
# 12.86    0.000799
# 10.80    0.000799
# 9.17     0.000799
# 9.60     0.000799
# 11.50    0.000776
# 17.40    0.000776
# 6.76     0.000776
# 10.64    0.000776
# 13.75    0.000752
# 14.40    0.000752
#            ...
# 29.01    0.000024
# 29.82    0.000024
# 28.16    0.000024
# 27.69    0.000024
# 27.36    0.000024
# 28.43    0.000024
# 28.77    0.000024
# 25.44    0.000024
# 27.23    0.000024
# 29.28    0.000024
# 27.07    0.000024
# 27.10    0.000024
# 26.38    0.000024
# 27.52    0.000024
# 25.58    0.000024
# 25.24    0.000024
# 27.79    0.000024
# 26.74    0.000024
# 25.20    0.000024
# 29.48    0.000024
# 27.03    0.000024
# 28.55    0.000024
# 28.60    0.000024
# 28.64    0.000024
# 27.87    0.000024
# 26.99    0.000024
# 27.81    0.000024
# 27.82    0.000024
# 25.87    0.000024
# 25.37    0.000024
# Name: dti, Length: 2894, dtype: float64

# %%
print("counts/percentages for revolving utilization rate")
c1 = pdLoans["revol_util_d"].value_counts(sort=True)
p1 = pdLoans["revol_util_d"].value_counts(sort=True, normalize=True)
print(c1)
print('')
print(p1)
# Out:
# counts/percentages for revolving utilization rate
# 0.0000    1070
# 0.4070      65
# 0.0020      64
# 0.6300      63
# 0.6660      62
# 0.0010      61
# 0.7040      61
# 0.3760      60
# 0.6460      60
# 0.3120      59
# 0.4640      59
# 0.6670      59
# 0.3530      59
# 0.5740      58
# 0.4660      58
# 0.8950      58
# 0.7660      58
# 0.2550      58
# 0.7870      58
# 0.5580      58
# 0.6100      58
# 0.6590      57
# 0.4890      57
# 0.6690      57
# 0.4980      57
# 0.7210      57
# 0.6860      57
# 0.3440      57
# 0.4560      56
# 0.4100      56
#           ...
# 1.0640       1
# 0.0534       1
# 0.0743       1
# 0.5819       1
# 0.5258       1
# 0.4338       1
# 0.3763       1
# 0.0001       1
# 0.2465       1
# 0.0858       1
# 0.4361       1
# 1.0430       1
# 0.0003       1
# 0.0046       1
# 0.0579       1
# 0.1771       1
# 0.8131       1
# 0.4963       1
# 1.0270       1
# 1.0420       1
# 0.2841       1
# 0.0485       1
# 0.9446       1
# 0.0264       1
# 0.5877       1
# 0.2953       1
# 0.2632       1
# 0.5422       1
# 0.4185       1
# 0.2466       1
# Name: revol_util_d, Length: 1119, dtype: int64
#
# 0.0000    0.025209
# 0.4070    0.001531
# 0.0020    0.001508
# 0.6300    0.001484
# 0.6660    0.001461
# 0.0010    0.001437
# 0.7040    0.001437
# 0.3760    0.001414
# 0.6460    0.001414
# 0.3120    0.001390
# 0.4640    0.001390
# 0.6670    0.001390
# 0.3530    0.001390
# 0.5740    0.001366
# 0.4660    0.001366
# 0.8950    0.001366
# 0.7660    0.001366
# 0.2550    0.001366
# 0.7870    0.001366
# 0.5580    0.001366
# 0.6100    0.001366
# 0.6590    0.001343
# 0.4890    0.001343
# 0.6690    0.001343
# 0.4980    0.001343
# 0.7210    0.001343
# 0.6860    0.001343
# 0.3440    0.001343
# 0.4560    0.001319
# 0.4100    0.001319
#             ...
# 1.0640    0.000024
# 0.0534    0.000024
# 0.0743    0.000024
# 0.5819    0.000024
# 0.5258    0.000024
# 0.4338    0.000024
# 0.3763    0.000024
# 0.0001    0.000024
# 0.2465    0.000024
# 0.0858    0.000024
# 0.4361    0.000024
# 1.0430    0.000024
# 0.0003    0.000024
# 0.0046    0.000024
# 0.0579    0.000024
# 0.1771    0.000024
# 0.8131    0.000024
# 0.4963    0.000024
# 1.0270    0.000024
# 1.0420    0.000024
# 0.2841    0.000024
# 0.0485    0.000024
# 0.9446    0.000024
# 0.0264    0.000024
# 0.5877    0.000024
# 0.2953    0.000024
# 0.2632    0.000024
# 0.5422    0.000024
# 0.4185    0.000024
# 0.2466    0.000024
# Name: revol_util_d, Length: 1119, dtype: float64

# %%
print("counts/percentages for recoveries")
c1 = pdLoans["recoveries"].value_counts(sort=True)
p1 = pdLoans["recoveries"].value_counts(sort=True, normalize=True)
print(c1)
print('')
print(p1)
# Out:
# counts/percentages for recoveries
# 0.00       36188
# 0.30          14
# 1.80          11
# 0.96          11
# 4.20          10
# 1.20          10
# 0.90           9
# 1.15           9
# 1.76           9
# 0.26           9
# 0.72           9
# 6.30           9
# 2.40           8
# 0.35           8
# 0.98           8
# 0.54           8
# 0.70           8
# 0.68           8
# 0.14           8
# 3.90           8
# 0.06           8
# 0.56           8
# 0.36           8
# 4.80           7
# 1.44           7
# 0.52           7
# 3.36           7
# 7.14           7
# 0.01           7
# 3.60           7
#            ...
# 3915.78        1
# 260.14         1
# 163.93         1
# 375.26         1
# 1700.14        1
# 2116.47        1
# 456.59         1
# 1040.81        1
# 274.13         1
# 257.70         1
# 240.15         1
# 529.93         1
# 722.12         1
# 203.97         1
# 1024.20        1
# 244.58         1
# 228.42         1
# 1425.81        1
# 173.62         1
# 548.76         1
# 385.95         1
# 7978.52        1
# 175.37         1
# 2377.03        1
# 2.65           1
# 92.66          1
# 1060.39        1
# 729.64         1
# 188.63         1
# 308.02         1
# Name: recoveries, Length: 5045, dtype: int64
#
# 0.00       0.850782
# 0.30       0.000329
# 1.80       0.000259
# 0.96       0.000259
# 4.20       0.000235
# 1.20       0.000235
# 0.90       0.000212
# 1.15       0.000212
# 1.76       0.000212
# 0.26       0.000212
# 0.72       0.000212
# 6.30       0.000212
# 2.40       0.000188
# 0.35       0.000188
# 0.98       0.000188
# 0.54       0.000188
# 0.70       0.000188
# 0.68       0.000188
# 0.14       0.000188
# 3.90       0.000188
# 0.06       0.000188
# 0.56       0.000188
# 0.36       0.000188
# 4.80       0.000165
# 1.44       0.000165
# 0.52       0.000165
# 3.36       0.000165
# 7.14       0.000165
# 0.01       0.000165
# 3.60       0.000165
#              ...
# 3915.78    0.000024
# 260.14     0.000024
# 163.93     0.000024
# 375.26     0.000024
# 1700.14    0.000024
# 2116.47    0.000024
# 456.59     0.000024
# 1040.81    0.000024
# 274.13     0.000024
# 257.70     0.000024
# 240.15     0.000024
# 529.93     0.000024
# 722.12     0.000024
# 203.97     0.000024
# 1024.20    0.000024
# 244.58     0.000024
# 228.42     0.000024
# 1425.81    0.000024
# 173.62     0.000024
# 548.76     0.000024
# 385.95     0.000024
# 7978.52    0.000024
# 175.37     0.000024
# 2377.03    0.000024
# 2.65       0.000024
# 92.66      0.000024
# 1060.39    0.000024
# 729.64     0.000024
# 188.63     0.000024
# 308.02     0.000024
# Name: recoveries, Length: 5045, dtype: float64
